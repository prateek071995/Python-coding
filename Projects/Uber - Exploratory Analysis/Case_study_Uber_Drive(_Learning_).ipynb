# %% [markdown]
# # **Uber Drive Analysis**

# %% [markdown]
# Question 1 - Import the dataset ('Uber data')

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/Course Internship Training/Relevel/Class 64  to 78 - Python/Class 79/Uber data - Sheet1.csv")

# %%
data
# Out:
#      START_DATE*   END_DATE* CATEGORY*            START*             STOP*  \
# 0     08-06-2012  12-06-2012  Business       Fort Pierce       Fort Pierce
# 1     24-07-2019  02-08-2019  Business       Fort Pierce       Fort Pierce
# 2     01-05-2018  02-05-2018  Business       Fort Pierce       Fort Pierce
# 3     25-08-2015  03-09-2015  Business       Fort Pierce       Fort Pierce
# 4     03-12-2011  05-12-2011  Business       Fort Pierce   West Palm Beach
# ...          ...         ...       ...               ...               ...
# 1150  12-08-2011  14-08-2011  Business           Kar?chi           Kar?chi
# 1151  19-03-2011  29-03-2011  Business           Kar?chi  Unknown Location
# 1152  27-05-2010  27-05-2010  Business  Unknown Location  Unknown Location
# 1153  29-09-2014  04-10-2014  Business        Katunayake           Gampaha
# 1154  04-01-2015  12-01-2015  Business           Gampaha         Ilukwatta
#
#       MILES*         PURPOSE*
# 0        5.1   Meal/Entertain
# ...

# %% [markdown]
# Question 2- Write a code to get the top 7 rows of the dataset

# %%
data.head(7)
# Out:
#   START_DATE*   END_DATE* CATEGORY*           START*            STOP*  MILES*  \
# 0  08-06-2012  12-06-2012  Business      Fort Pierce      Fort Pierce     5.1
# 1  24-07-2019  02-08-2019  Business      Fort Pierce      Fort Pierce     5.0
# 2  01-05-2018  02-05-2018  Business      Fort Pierce      Fort Pierce     4.8
# 3  25-08-2015  03-09-2015  Business      Fort Pierce      Fort Pierce     4.7
# 4  03-12-2011  05-12-2011  Business      Fort Pierce  West Palm Beach    63.7
# 5  14-12-2010  15-12-2010  Business  West Palm Beach  West Palm Beach     4.3
# 6  27-04-2012  04-05-2012  Business  West Palm Beach       Palm Beach     7.1
#
#           PURPOSE*
# 0   Meal/Entertain
# 1              NaN
# 2  Errand/Supplies
# 3          Meeting
# 4   Customer Visit
# 5   Meal/Entertain
# 6          Meeting

# %% [markdown]
# Question 3 - Write a code to get the last 5 rows of the dataset.

# %%
data.tail(5)
# Out:
#      START_DATE*   END_DATE* CATEGORY*            START*             STOP*  \
# 1150  12-08-2011  14-08-2011  Business           Kar?chi           Kar?chi
# 1151  19-03-2011  29-03-2011  Business           Kar?chi  Unknown Location
# 1152  27-05-2010  27-05-2010  Business  Unknown Location  Unknown Location
# 1153  29-09-2014  04-10-2014  Business        Katunayake           Gampaha
# 1154  04-01-2015  12-01-2015  Business           Gampaha         Ilukwatta
#
#       MILES*        PURPOSE*
# 1150     0.7         Meeting
# 1151     3.9  Temporary Site
# 1152    16.2         Meeting
# 1153     6.4  Temporary Site
# 1154    48.2  Temporary Site

# %% [markdown]
# Question 4 - Get the total number of rows and columns in the dataset

# %%
#  Method - 1


data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
#  Method - 2


print('Total no. of Rows - ' , len(data))

print('Total no. of columns - ' ,len(data.columns))
# Out:
# Total no. of Rows -  1155
# Total no. of columns -  7

# %%
#  Method - 3

# computing number of rows
rows = len(data.axes[0])
 
# computing number of columns
cols = len(data.axes[1])

print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
# Number of Rows:  1155
# Number of Columns:  7

# %%
# Method - 4

# obtaining the shape
print("shape of dataframe", data.shape)
 
# obtaining the number of rows
print("number of rows : ", data.shape[0])
 
# obtaining the number of columns
print("number of columns : ", data.shape[1])
# Out:
# shape of dataframe (1155, 7)
# number of rows :  1155
# number of columns :  7

# %% [markdown]
# Question 5 - Get the total number of elements in the dataset (Use size function).

# %%
data.size
# Out:
# 8085

# %% [markdown]
# Question 6 - Write a code to get the total number of NULL values across every column in the dataset

# %%
data.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %% [markdown]
# Question 7 - Write a code to get the total number of Non-NULL values across every column in the dataset.

# %%
data.notnull().sum()
# Out:
# START_DATE*    1155
# END_DATE*      1155
# CATEGORY*      1155
# START*         1155
# STOP*          1155
# MILES*         1155
# PURPOSE*        653
# dtype: int64

# %% [markdown]
# Question 8 - Write a code to get the entries having NULL values in the 'Purpose' column

# %%
data[data['PURPOSE*'].isnull()]
# Out:
#      START_DATE*   END_DATE* CATEGORY*            START*                STOP*  \
# 1     24-07-2019  02-08-2019  Business       Fort Pierce          Fort Pierce
# 32    25-03-2015  28-03-2015  Business       Whitebridge  Lake Wellingborough
# 85    28-09-2020  07-10-2020  Personal       Whitebridge           Northwoods
# 86    21-07-2018  26-07-2018  Personal        Northwoods           Tanglewood
# 87    23-01-2014  26-01-2014  Personal        Tanglewood              Preston
# ...          ...         ...       ...               ...                  ...
# 1065  07-02-2020  08-02-2020  Business  Unknown Location     Unknown Location
# 1066  23-08-2019  30-08-2019  Business  Unknown Location     Unknown Location
# 1069  18-05-2020  23-05-2020  Business         Islamabad     Unknown Location
# 1071  02-12-2018  09-12-2018  Business  Unknown Location           Rawalpindi
# 1143  13-07-2016  21-07-2016  Business           Kar?chi     Unknown Location
#
#       MILES* PURPOSE*
# ...

# %% [markdown]
# Question 9 - Write a code to get the entries having Non-NULL values in the 'Purpose' column using the Tilde (~) operator.

# %%
data[~data['PURPOSE*'].isnull()]
# Out:
#      START_DATE*   END_DATE* CATEGORY*            START*             STOP*  \
# 0     08-06-2012  12-06-2012  Business       Fort Pierce       Fort Pierce
# 2     01-05-2018  02-05-2018  Business       Fort Pierce       Fort Pierce
# 3     25-08-2015  03-09-2015  Business       Fort Pierce       Fort Pierce
# 4     03-12-2011  05-12-2011  Business       Fort Pierce   West Palm Beach
# 5     14-12-2010  15-12-2010  Business   West Palm Beach   West Palm Beach
# ...          ...         ...       ...               ...               ...
# 1150  12-08-2011  14-08-2011  Business           Kar?chi           Kar?chi
# 1151  19-03-2011  29-03-2011  Business           Kar?chi  Unknown Location
# 1152  27-05-2010  27-05-2010  Business  Unknown Location  Unknown Location
# 1153  29-09-2014  04-10-2014  Business        Katunayake           Gampaha
# 1154  04-01-2015  12-01-2015  Business           Gampaha         Ilukwatta
#
#       MILES*         PURPOSE*
# 0        5.1   Meal/Entertain
# ...

# %% [markdown]
# Question 10 - Write a code to get Non-NULL entries in the PURPOSE column.

# %%
data[data['PURPOSE*'].notnull()]
# Out:
#      START_DATE*   END_DATE* CATEGORY*            START*             STOP*  \
# 0     08-06-2012  12-06-2012  Business       Fort Pierce       Fort Pierce
# 2     01-05-2018  02-05-2018  Business       Fort Pierce       Fort Pierce
# 3     25-08-2015  03-09-2015  Business       Fort Pierce       Fort Pierce
# 4     03-12-2011  05-12-2011  Business       Fort Pierce   West Palm Beach
# 5     14-12-2010  15-12-2010  Business   West Palm Beach   West Palm Beach
# ...          ...         ...       ...               ...               ...
# 1150  12-08-2011  14-08-2011  Business           Kar?chi           Kar?chi
# 1151  19-03-2011  29-03-2011  Business           Kar?chi  Unknown Location
# 1152  27-05-2010  27-05-2010  Business  Unknown Location  Unknown Location
# 1153  29-09-2014  04-10-2014  Business        Katunayake           Gampaha
# 1154  04-01-2015  12-01-2015  Business           Gampaha         Ilukwatta
#
#       MILES*         PURPOSE*
# 0        5.1   Meal/Entertain
# ...

# %% [markdown]
# Question 11 - Write a code to remove the * in every column name using the rename function.

# %%
data.rename(columns = {'START_DATE*':'START_DATE','END_DATE*':'END_DATE',}, inplace=True)
data
# Out:
#       START_DATE    END_DATE CATEGORY*            START*             STOP*  \
# 0     08-06-2012  12-06-2012  Business       Fort Pierce       Fort Pierce
# 1     24-07-2019  02-08-2019  Business       Fort Pierce       Fort Pierce
# 2     01-05-2018  02-05-2018  Business       Fort Pierce       Fort Pierce
# 3     25-08-2015  03-09-2015  Business       Fort Pierce       Fort Pierce
# 4     03-12-2011  05-12-2011  Business       Fort Pierce   West Palm Beach
# ...          ...         ...       ...               ...               ...
# 1150  12-08-2011  14-08-2011  Business           Kar?chi           Kar?chi
# 1151  19-03-2011  29-03-2011  Business           Kar?chi  Unknown Location
# 1152  27-05-2010  27-05-2010  Business  Unknown Location  Unknown Location
# 1153  29-09-2014  04-10-2014  Business        Katunayake           Gampaha
# 1154  04-01-2015  12-01-2015  Business           Gampaha         Ilukwatta
#
#       MILES*         PURPOSE*
# 0        5.1   Meal/Entertain
# ...

# %% [markdown]
# Question 12 - Write a code to remove the * in every column name using the str.replace() function.

# %%
data.columns = data.columns.str.replace('*','')

data
# Out:
# <ipython-input-53-d7b084d70893>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.columns = data.columns.str.replace('*','')
#       START_DATE    END_DATE  CATEGORY             START              STOP  \
# 0     08-06-2012  12-06-2012  Business       Fort Pierce       Fort Pierce
# 1     24-07-2019  02-08-2019  Business       Fort Pierce       Fort Pierce
# 2     01-05-2018  02-05-2018  Business       Fort Pierce       Fort Pierce
# 3     25-08-2015  03-09-2015  Business       Fort Pierce       Fort Pierce
# 4     03-12-2011  05-12-2011  Business       Fort Pierce   West Palm Beach
# ...          ...         ...       ...               ...               ...
# 1150  12-08-2011  14-08-2011  Business           Kar?chi           Kar?chi
# 1151  19-03-2011  29-03-2011  Business           Kar?chi  Unknown Location
# ...

# %% [markdown]
# Question 13 - Write a code to remove the * in every column name using the lambda function.

# %% [markdown]
# Question 14 - Get the entries in the data where the START location is 'Fort Pierce'.

# %%
data[data['START']=='Fort Pierce']
# Out:
#    START_DATE    END_DATE  CATEGORY        START             STOP  MILES  \
# 0  08-06-2012  12-06-2012  Business  Fort Pierce      Fort Pierce    5.1
# 1  24-07-2019  02-08-2019  Business  Fort Pierce      Fort Pierce    5.0
# 2  01-05-2018  02-05-2018  Business  Fort Pierce      Fort Pierce    4.8
# 3  25-08-2015  03-09-2015  Business  Fort Pierce      Fort Pierce    4.7
# 4  03-12-2011  05-12-2011  Business  Fort Pierce  West Palm Beach   63.7
#
#            PURPOSE
# 0   Meal/Entertain
# 1              NaN
# 2  Errand/Supplies
# 3          Meeting
# 4   Customer Visit

# %% [markdown]
# Question 15 - Get the entries in the data where the STOP location is 'Fort Pierce'.

# %%
data[data['STOP']=='Fort Pierce']
# Out:
#    START_DATE    END_DATE  CATEGORY        START         STOP  MILES  \
# 0  08-06-2012  12-06-2012  Business  Fort Pierce  Fort Pierce    5.1
# 1  24-07-2019  02-08-2019  Business  Fort Pierce  Fort Pierce    5.0
# 2  01-05-2018  02-05-2018  Business  Fort Pierce  Fort Pierce    4.8
# 3  25-08-2015  03-09-2015  Business  Fort Pierce  Fort Pierce    4.7
#
#            PURPOSE
# 0   Meal/Entertain
# 1              NaN
# 2  Errand/Supplies
# 3          Meeting

# %% [markdown]
# Question 16 - Write a code to sort the entries in the data in descending order of the 'MILES' column.

# %%
data.sort_values('MILES', ascending=False)
# Out:
#       START_DATE    END_DATE  CATEGORY             START              STOP  \
# 269   28-10-2020  28-10-2020  Business             Latta      Jacksonville
# 270   06-03-2013  09-03-2013  Business      Jacksonville         Kissimmee
# 881   10-01-2015  10-01-2015  Business         Asheville            Mebane
# 776   20-11-2012  20-11-2012  Business  Unknown Location  Unknown Location
# 546   25-07-2015  29-07-2015  Business       Morrisville        Banner Elk
# ...          ...         ...       ...               ...               ...
# 945   05-07-2013  11-07-2013  Business           Central     West Berkeley
# 1121  13-01-2018  13-01-2018  Business           Kar?chi           Kar?chi
# 420   08-05-2018  17-05-2018  Business              Soho           Tribeca
# 44    05-09-2010  13-09-2010  Business              Cary              Cary
# 120   01-11-2015  09-11-2015  Business        Katunayaka        Katunayaka
#
#       MILES          PURPOSE
# 269   310.3   Customer Visit
# ...

# %% [markdown]
# Question 17 - Write a code to drop all the rows where there are NULL values in the STOP column.

# %%
data[data['STOP'].notnull()]
# Out:
#       START_DATE    END_DATE  CATEGORY             START              STOP  \
# 0     08-06-2012  12-06-2012  Business       Fort Pierce       Fort Pierce
# 1     24-07-2019  02-08-2019  Business       Fort Pierce       Fort Pierce
# 2     01-05-2018  02-05-2018  Business       Fort Pierce       Fort Pierce
# 3     25-08-2015  03-09-2015  Business       Fort Pierce       Fort Pierce
# 4     03-12-2011  05-12-2011  Business       Fort Pierce   West Palm Beach
# ...          ...         ...       ...               ...               ...
# 1150  12-08-2011  14-08-2011  Business           Kar?chi           Kar?chi
# 1151  19-03-2011  29-03-2011  Business           Kar?chi  Unknown Location
# 1152  27-05-2010  27-05-2010  Business  Unknown Location  Unknown Location
# 1153  29-09-2014  04-10-2014  Business        Katunayake           Gampaha
# 1154  04-01-2015  12-01-2015  Business           Gampaha         Ilukwatta
#
#       MILES          PURPOSE
# 0       5.1   Meal/Entertain
# ...

# %% [markdown]
# Question 18 - Use describe() function to get the Statistical Properties about the numerical columns in the data.

# %%
data.describe()
# Out:
#              MILES
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %% [markdown]
# Question 19 - Create a report in an html file using pandas profiling.

# %% [markdown]
# Question 20 - Get the unique and total number of unique values in the START and STOP column of the data.

# %%
# Unique values
data['START'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
# ...

# %%
# Total number of unique values
len(data['START'].unique())
# Out:
# 177

# %%
# Total number of unique values
print(len(data['STOP'].unique()))

# Unique values
print(data['STOP'].unique())
# Out:
# 188
# ['Fort Pierce' 'West Palm Beach' 'Palm Beach' 'Cary' 'Morrisville'
#  'New York' 'Queens' 'East Harlem' 'NoMad' 'Midtown' 'Midtown East'
#  'Hudson Square' 'Lower Manhattan' "Hell's Kitchen" 'Queens County'
#  'Gulfton' 'Downtown' 'Houston' 'Jamestown Court' 'Durham' 'Whitebridge'
#  'Lake Wellingborough' 'Raleigh' 'Umstead' 'Hazelwood' 'Westpark Place'
#  'Meredith Townes' 'Leesville Hollow' 'Apex' 'Chapel Hill'
#  'Williamsburg Manor' 'Macgregor Downs' 'Edgehill Farms' 'Northwoods'
#  'Tanglewood' 'Preston' 'Walnut Terrace' 'Jackson Heights' 'East Elmhurst'
#  'Midtown West' 'Long Island City' 'Jamaica' 'Unknown Location' 'Colombo'
#  'Nugegoda' 'Katunayaka' 'Islamabad' 'R?walpindi' 'Noorpur Shahan'
#  'Heritage Pines' 'Waverly Place' 'Wayne Ridge' 'Depot Historic District'
#  'Weston' 'West University' 'South Congress' 'Arts District'
#  'Congress Ave District' 'Red River District' 'The Drag'
#  'Convention Center District' 'North Austin' 'Coxville' 'Katy' 'Alief'
# ...

# %% [markdown]
# Question 21 - Get the rides where we have the same START and STOP locations using a comparison operator (==).

# %%
data[data['START']==data['STOP']]
# Out:
#       START_DATE    END_DATE  CATEGORY             START              STOP  \
# 0     08-06-2012  12-06-2012  Business       Fort Pierce       Fort Pierce
# 1     24-07-2019  02-08-2019  Business       Fort Pierce       Fort Pierce
# 2     01-05-2018  02-05-2018  Business       Fort Pierce       Fort Pierce
# 3     25-08-2015  03-09-2015  Business       Fort Pierce       Fort Pierce
# 5     14-12-2010  15-12-2010  Business   West Palm Beach   West Palm Beach
# ...          ...         ...       ...               ...               ...
# 1147  25-08-2016  28-08-2016  Business           Kar?chi           Kar?chi
# 1148  25-03-2013  26-03-2013  Business           Kar?chi           Kar?chi
# 1149  26-02-2015  05-03-2015  Business           Kar?chi           Kar?chi
# 1150  12-08-2011  14-08-2011  Business           Kar?chi           Kar?chi
# 1152  27-05-2010  27-05-2010  Business  Unknown Location  Unknown Location
#
#       MILES          PURPOSE
# 0       5.1   Meal/Entertain
# ...

# %% [markdown]
# Question 22 - Get the rides where we have the same START and STOP locations using a membership operator.

# %%
data[data['START'].isin(data['STOP'])]
# Out:
#       START_DATE    END_DATE  CATEGORY             START              STOP  \
# 0     08-06-2012  12-06-2012  Business       Fort Pierce       Fort Pierce
# 1     24-07-2019  02-08-2019  Business       Fort Pierce       Fort Pierce
# 2     01-05-2018  02-05-2018  Business       Fort Pierce       Fort Pierce
# 3     25-08-2015  03-09-2015  Business       Fort Pierce       Fort Pierce
# 4     03-12-2011  05-12-2011  Business       Fort Pierce   West Palm Beach
# ...          ...         ...       ...               ...               ...
# 1149  26-02-2015  05-03-2015  Business           Kar?chi           Kar?chi
# 1150  12-08-2011  14-08-2011  Business           Kar?chi           Kar?chi
# 1151  19-03-2011  29-03-2011  Business           Kar?chi  Unknown Location
# 1152  27-05-2010  27-05-2010  Business  Unknown Location  Unknown Location
# 1154  04-01-2015  12-01-2015  Business           Gampaha         Ilukwatta
#
#       MILES          PURPOSE
# 0       5.1   Meal/Entertain
# ...

# %% [markdown]
# Question 23 - Use value_counts() function to demonstrate the proportion of different categorical values in the data.

# %%
data.value_counts()
# Out:
# START_DATE  END_DATE    CATEGORY  START             STOP              MILES  PURPOSE
# 01-02-2011  04-02-2011  Business  Sugar Land        Houston           35.1   Customer Visit     1
# 22-11-2013  26-11-2013  Business  Unknown Location  Unknown Location  7.7    Temporary Site     1
# 22-01-2017  30-01-2017  Business  Wayne Ridge       Whitebridge       8.0    Meal/Entertain     1
# 22-02-2018  02-03-2018  Business  Durham            Cary              9.9    Meeting            1
# 22-04-2011  24-04-2011  Business  Whitebridge       Macgregor Downs   9.0    Meeting            1
#                                                                                                ..
# 11-11-2014  15-11-2014  Business  Morrisville       Morrisville       11.8   Errand/Supplies    1
# 11-11-2019  18-11-2019  Business  Whitebridge       Whitebridge       4.2    Meal/Entertain     1
# 11-12-2013  17-12-2013  Business  San Francisco     Emeryville        11.6   Meeting            1
# ...

# %% [markdown]
# Question 24 -Get the number of rides where START and STOP locations are the same

# %%
len(data[data['START']==data['STOP']])
# Out:
# 288

# %%
data[data['START']==data['STOP']].value_counts()
# Out:
# START_DATE  END_DATE    CATEGORY  START             STOP              MILES  PURPOSE
# 01-03-2012  02-03-2012  Business  Cary              Cary              5.2    Meeting            1
# 21-06-2012  26-06-2012  Business  Cary              Cary              3.4    Errand/Supplies    1
# 20-10-2020  23-10-2020  Business  Lahore            Lahore            2.1    Customer Visit     1
# 20-11-2010  26-11-2010  Business  Cary              Cary              1.6    Errand/Supplies    1
# 20-12-2017  22-12-2017  Business  Cary              Cary              1.6    Meal/Entertain     1
#                                                                                                ..
# 08-08-2011  12-08-2011  Business  Weston            Weston            3.8    Meal/Entertain     1
# 08-06-2012  12-06-2012  Business  Fort Pierce       Fort Pierce       5.1    Meal/Entertain     1
# 08-04-2014  12-04-2014  Business  Cary              Cary              1.8    Meeting            1
# ...

# %% [markdown]
# Question 25 - Find the favorite starting point according the the total number of MILES covered. (Use groupby function).

# %%
data.groupby(['START'])['MILES'].sum().sort_values(ascending = False).head(1)
# Out:
# START
# Unknown Location    1976.5
# Name: MILES, dtype: float64

# %% [markdown]
# Question 26 - Find the starting point for the ride where maximum miles are covered.

# %%
data[['START','MILES']].sort_values(by='MILES',ascending = False)
# Out:
#                  START  MILES
# 269              Latta  310.3
# 270       Jacksonville  201.0
# 881          Asheville  195.9
# 776   Unknown Location  195.6
# 546        Morrisville  195.3
# ...                ...    ...
# 945            Central    0.6
# 1121           Kar?chi    0.6
# 420               Soho    0.5
# 44                Cary    0.5
# 120         Katunayaka    0.5
#
# [1155 rows x 2 columns]

# %% [markdown]
# Question 27 - Check the data types of all the columns in the dataset.

# %%
data.dtypes
# Out:
# START_DATE     object
# END_DATE       object
# CATEGORY       object
# START          object
# STOP           object
# MILES         float64
# PURPOSE        object
# dtype: object

# %% [markdown]
# Question 28 - Drop the 'unknown location' value from START and STOP column.

# %%
data[(data['START']!='Unknown Location') & (data['STOP']!='Unknown Location')]
# Out:
#       START_DATE    END_DATE  CATEGORY        START             STOP  MILES  \
# 0     08-06-2012  12-06-2012  Business  Fort Pierce      Fort Pierce    5.1
# 1     24-07-2019  02-08-2019  Business  Fort Pierce      Fort Pierce    5.0
# 2     01-05-2018  02-05-2018  Business  Fort Pierce      Fort Pierce    4.8
# 3     25-08-2015  03-09-2015  Business  Fort Pierce      Fort Pierce    4.7
# 4     03-12-2011  05-12-2011  Business  Fort Pierce  West Palm Beach   63.7
# ...          ...         ...       ...          ...              ...    ...
# 1148  25-03-2013  26-03-2013  Business      Kar?chi          Kar?chi    4.6
# 1149  26-02-2015  05-03-2015  Business      Kar?chi          Kar?chi    0.8
# 1150  12-08-2011  14-08-2011  Business      Kar?chi          Kar?chi    0.7
# 1153  29-09-2014  04-10-2014  Business   Katunayake          Gampaha    6.4
# 1154  04-01-2015  12-01-2015  Business      Gampaha        Ilukwatta   48.2
#
#               PURPOSE
# 0      Meal/Entertain
# ...

# %% [markdown]
# Question 29 - Find the most popular START-STOP pair according to the total number of rides covered.

# %%
data.groupby(['START','STOP']).size().sort_values(ascending = False).head(1)
# Out:
# START             STOP
# Unknown Location  Unknown Location    86
# dtype: int64

# %% [markdown]
# Question 30 - Convert the datatypes of START_DATE and END_DATE columns to datetime.

# %%
# SOLUTION IS RIGHT BUT DATA IN THESE COLUMN IS WRONG , THATS WHY NOT WORKING

data['START_DATE'] = pd.to_datetime(data['START_DATE'])

data['STOP_DATE'] = pd.to_datetime(data['STOP_DATE'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'STOP_DATE'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# Question 31 - Extract the month from START_DATE and try to get the proportion of rides of different months.

# %% [markdown]
# Question 32. Find the average distance covered each month.

# %% [markdown]
# Question 33. Extract the day from the START_DATE column.

# %% [markdown]
# Question 34. Find the total miles covered per category per purpose.

# %%
data.groupby(['PURPOSE','CATEGORY'])['MILES'].sum().sort_values(ascending = True)

# %% [markdown]
# Question 35. Find the percentage of Business Miles covered and Personal mIles covered

# %%
business_miles = data[data['CATEGORY']=='Business'].groupby(['CATEGORY'])['MILES'].sum()
print(business_miles)


personal_miles = data[data['CATEGORY']=='Personal'].groupby(['CATEGORY'])['MILES'].sum()
print(personal_miles)

total_miles = data['MILES'].sum()
print(total_miles)

per_business_miles = (business_miles / total_miles)*100
print('Percentage of Business Miles Covered - ',per_business_miles )


per_personal_miles = (personal_miles / total_miles)*100

print('Percentage of Personal Miles Covered - ',per_personal_miles )
